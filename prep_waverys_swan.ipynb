# %%
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt

# %%
pth = '/mnt/c/Users/henri/OneDrive - atmosmarine.com/database/WAVERYS/'

ds = xr.open_dataset(pth + 'WAVERYS_PNBOIA.nc')

# %%
ds
# Out:
# <xarray.Dataset> Size: 289GB
# Dimensions:    (time: 126608, latitude: 111, longitude: 151)
# Coordinates:
#   * latitude   (latitude) float32 444B -52.0 -51.8 -51.6 ... -30.4 -30.2 -30.0
#   * longitude  (longitude) float32 604B -35.0 -34.8 -34.6 ... -5.4 -5.2 -5.0
#   * time       (time) datetime64[ns] 1MB 1980-01-01 ... 2023-04-30T21:00:00
# Data variables: (12/17)
#     VHM0       (time, latitude, longitude) float64 17GB ...
#     VHM0_SW1   (time, latitude, longitude) float64 17GB ...
#     VHM0_SW2   (time, latitude, longitude) float64 17GB ...
#     VHM0_WW    (time, latitude, longitude) float64 17GB ...
#     VMDR       (time, latitude, longitude) float64 17GB ...
#     VMDR_SW1   (time, latitude, longitude) float64 17GB ...
#     ...         ...
#     VTM01_SW1  (time, latitude, longitude) float64 17GB ...
#     VTM01_SW2  (time, latitude, longitude) float64 17GB ...
#     VTM01_WW   (time, latitude, longitude) float64 17GB ...
# ...
